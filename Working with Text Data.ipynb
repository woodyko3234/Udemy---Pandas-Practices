# %%
import pandas as pd 
import numpy as np

# %%
chicago = pd.read_csv("pandas/chicago.csv")
chicago["Department"] = chicago["Department"].astype("category")
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null object
# dtypes: category(1), object(3)
# memory usage: 784.4+ KB

# %%
chicago["Department"].nunique()
# Out:
# 35

# %%
chicago["Department"].count()
# Out:
# 32062

# %%
chicago['Name'].str.lower()
# Out:
# 0                 aaron,  elvia j
# 1               aaron,  jeffery m
# 2                  aaron,  karina
# 3             aaron,  kimberlei r
# 4             abad jr,  vicente m
# 5                 abarca,  anabel
# 6               abarca,  emmanuel
# 7               abascal,  reece e
# 8            abbasi,  christopher
# 9           abbatacola,  robert j
# 10          abbatemarco,  james j
# 11               abbate,  terry m
# 12               abbott,  betty l
# 13              abbott,  lynise m
# 14         abbruzzese,  william j
# 15                abdallah,  zaid
# 16          abdelhadi,  abdalmahd
# 17            abdellatif,  aref r
# 18             abdelmajeid,  aziz
# 19            abdollahzadeh,  ali
# 20       abdul-karim,  muhammad a
# 21            abdullah,  daniel n
# 22               abdullah,  kevin
# 23           abdullah,  lakenya n
# 24            abdullah,  rashad j
# 25           abdulsattar,  mudhar
# 26           abdul-shakur,  tahir
# ...

# %%
chicago['Name'].str.title()
# Out:
# 0                 Aaron,  Elvia J
# 1               Aaron,  Jeffery M
# 2                  Aaron,  Karina
# 3             Aaron,  Kimberlei R
# 4             Abad Jr,  Vicente M
# 5                 Abarca,  Anabel
# 6               Abarca,  Emmanuel
# 7               Abascal,  Reece E
# 8            Abbasi,  Christopher
# 9           Abbatacola,  Robert J
# 10          Abbatemarco,  James J
# 11               Abbate,  Terry M
# 12               Abbott,  Betty L
# 13              Abbott,  Lynise M
# 14         Abbruzzese,  William J
# 15                Abdallah,  Zaid
# 16          Abdelhadi,  Abdalmahd
# 17            Abdellatif,  Aref R
# 18             Abdelmajeid,  Aziz
# 19            Abdollahzadeh,  Ali
# 20       Abdul-Karim,  Muhammad A
# 21            Abdullah,  Daniel N
# 22               Abdullah,  Kevin
# 23           Abdullah,  Lakenya N
# 24            Abdullah,  Rashad J
# 25           Abdulsattar,  Mudhar
# 26           Abdul-Shakur,  Tahir
# ...

# %%
chicago = pd.read_csv('pandas/chicago.csv').dropna(how = 'all')

# %%
chicago['Department'] = chicago['Department'].str.replace('MGMNT', 'MANAGEMENT')

# %%
chicago['Employee Annual Salary'] = chicago['Employee Annual Salary'].str.replace('$', "").astype(float)

# %%
chicago['Employee Annual Salary'].describe()
# Out:
# count     32062.000000
# mean      80204.178634
# std       25098.329868
# min           0.960000
# 25%       72862.400000
# 50%       84450.000000
# 75%       93240.000000
# max      300000.000000
# Name: Employee Annual Salary, dtype: float64

# %%
chicago[chicago['Position Title'].str.title().str.startswith('Water')]
# Out:
#                           Name               Position Title        Department  \
# 0              AARON,  ELVIA J             WATER RATE TAKER  WATER MANAGEMENT
# 671            ANDER,  PERRY A             WATER CHEMIST II  WATER MANAGEMENT
# 1054          ASHLEY,  KARMA T             WATER CHEMIST II  WATER MANAGEMENT
# 1079         ATKINS,  JOANNA M             WATER CHEMIST II  WATER MANAGEMENT
# 1181        AZEEM,  MOHAMMED A             WATER CHEMIST II  WATER MANAGEMENT
# 1285            BAJIC,  JOHN A        WATER METER MACHINIST  WATER MANAGEMENT
# 2400          BOLTON,  BRIAN E             WATER RATE TAKER  WATER MANAGEMENT
# 2586           BOYCE,  ADNER L             WATER CHEMIST II  WATER MANAGEMENT
# 2745          BRANDYS,  DANIEL             WATER CHEMIST II  WATER MANAGEMENT
# 3143          BROWN,  SHARON L             WATER RATE TAKER  WATER MANAGEMENT
# 3246      BUCHANAN,  ANTHONY L             WATER CHEMIST II  WATER MANAGEMENT
# ...

# %%
chicago['Name'].str.split(',').str.get(1).str.strip().str.split(' ')[0:5]
# Out:
# 0        [ELVIA, J]
# 1      [JEFFERY, M]
# 2          [KARINA]
# 3    [KIMBERLEI, R]
# 4      [VICENTE, M]
# Name: Name, dtype: object

# %%
chicago[['First_Name', 'Last_Name']] = chicago['Name'].str.split(',', expand = True)

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER  WATER MANAGEMENT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV  WATER MANAGEMENT
#
#    Employee Annual Salary First_Name      Last_Name
# 0                 90744.0      AARON        ELVIA J
# 1                 84450.0      AARON      JEFFERY M
# 2                 84450.0      AARON         KARINA
# 3                 89880.0      AARON    KIMBERLEI R
# 4                106836.0    ABAD JR      VICENTE M

# %% [markdown]
# # Learned and useful methods

# %%
chicago['Employee Annual Salary'] = [str(value).replace("$", "") for value in chicago['Employee Annual Salary']]
chicago['Employee Annual Salary'].astype(float).sort_values(na_position = 'first')
# Out:
# 32062          NaN
# 15102         0.96
# 10932      2756.00
# 4507       2756.00
# 13347      2756.00
# 29962      2756.00
# 4523       2756.00
# 29974      2756.00
# 17647      2756.00
# 17661      2756.00
# 19692      2756.00
# 24644      2756.00
# 17671      2756.00
# 31091      2756.00
# 26906      2756.00
# 13262      2756.00
# 26637      2756.00
# 13210      2756.00
# 9951       2756.00
# 30028      2756.00
# 9983       2756.00
# 16204      2756.00
# 2118       2756.00
# 11235      2756.00
# 10043      2756.00
# 1525       2756.00
# 31572      2756.00
# 2921       2756.00
# 15470      2756.00
# 29256      2756.00
#            ...
# 12742    170112.00
# 12805    170112.00
# 6810     170112.00
# 27393    170112.00
# 16176    170112.00
# 30017    170112.00
# 21933    173664.00
# 14045    174720.00
# 19721    175002.00
# 7278     175002.00
# 23631    175020.00
# 19672    177000.00
# 7790     185352.00
# 20541    185352.00
# 9010     185352.00
# 26263    185352.00
# ...

# %%
chicago['Employee Annual Salary'].rank().sort_values() #output a rank series based on the selected data
# Out:
# 15102        1.0
# 21193       84.0
# 20332       84.0
# 6701        84.0
# 6768        84.0
# 30890       84.0
# 6846        84.0
# 28475       84.0
# 19988       84.0
# 19947       84.0
# 28581       84.0
# 396         84.0
# 395         84.0
# 28594       84.0
# 19776       84.0
# 19974       84.0
# 6206        84.0
# 6182        84.0
# 20837       84.0
# 5714        84.0
# 5716        84.0
# 5784        84.0
# 5806        84.0
# 5829        84.0
# 5849        84.0
# 7160        84.0
# 14430       84.0
# 20999       84.0
# 5968        84.0
# 5973        84.0
#           ...
# 27547    32041.0
# 9786     32041.0
# 9639     32041.0
# 7520     32041.0
# 2624     32041.0
# 9097     32041.0
# 8965     32041.0
# 8682     32041.0
# 21201    32041.0
# 184      32041.0
# 18244    32041.0
# 11679    32041.0
# 16260    32041.0
# 14524    32041.0
# 14501    32041.0
# 23475    32041.0
# 16980    32041.0
# 16988    32041.0
# 26214    32041.0
# 23058    32041.0
# 17187    32041.0
# ...

# %%
chicago['Employee Annual Salary'] = chicago['Employee Annual Salary'].astype(float)
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null float64
# dtypes: category(1), float64(1), object(2)
# memory usage: 784.4+ KB

# %%
chicago[chicago['Employee Annual Salary'].between(120000, 150000)]
# Out:
#                             Name                             Position Title  \
# 40             ABRAMSKI,  JOHN E                        AMBULANCE COMMANDER
# 87            ACHILLES,  AMBER L             CHIEF ASST CORPORATION COUNSEL
# 158              ADDUCI,  MARK A                                 LIEUTENANT
# 164             ADELIZZI,  JOY A                        DEPUTY COMMISSIONER
# 185              AGAR,  BULENT B                   CHIEF ENGINEER OF SEWERS
# 252              AHMED,  AMMAR E                 DIR OF INFORMATION SYSTEMS
# 256               AHMED,  NAFEES                        DEPUTY COMMISSIONER
# 263           AIKENS,  BRADLEY K                                CAPTAIN-EMT
# 315           ALBARRAN,  FRANK J  COORDINATING FIRE COMMUNICATIONS OPERATOR
# 374          ALEXANDER,  JAMES P                        AMBULANCE COMMANDER
# 549              ALTMAN,  MARK T                      BATTALION CHIEF - EMT
# ...

# %%
chicago[chicago["Department"].isin(['FIRE', 'LAW'])]
# Out:
#                           Name                                 Position Title  \
# 10       ABBATEMARCO,  JAMES J                              FIRE ENGINEER-EMT
# 17         ABDELLATIF,  AREF R  FIREFIGHTER (PER ARBITRATORS AWARD)-PARAMEDIC
# 19         ABDOLLAHZADEH,  ALI                          FIREFIGHTER/PARAMEDIC
# 21         ABDULLAH,  DANIEL N                                FIREFIGHTER-EMT
# 22            ABDULLAH,  KEVIN                                     LIEUTENANT
# 29     ABERCROMBIE IV,  EARL S                                      PARAMEDIC
# 40           ABRAMSKI,  JOHN E                            AMBULANCE COMMANDER
# 42         ABRATANSKI,  MARK A                                FIREFIGHTER-EMT
# 48              ABREU,  VICTOR                                FIREFIGHTER-EMT
# 68           ACEVEDO,  EDWIN C                                    FIREFIGHTER
# 71           ACEVEDO,  GILBERT                                 LIEUTENANT-EMT
# ...

# %%
chicago.drop_duplicates(subset = ["Employee Annual Salary"], keep = False)
# Out:
#                                 Name  \
# 5                    ABARCA,  ANABEL
# 164                 ADELIZZI,  JOY A
# 165                ADELMAN,  BRUCE E
# 261               AHUILE,  CECILIA T
# 318                   ALBERT,  LOUIS
# 521    ALONISTIOTIS,  KONSTANTINES M
# 527                 ALONSO,  MARIO A
# 614               ALVERIO,  EVELYN J
# 659                 AMSDEN,  MICHAEL
# 805              ANGELETTI,  DIANE E
# 821                      AN,  NICK H
# 861                APONTE,  WILFREDO
# 874                 AQUINO,  WILLIAM
# 917                   ARENA,  JOHN S
# 1033                 ARWADY,  MARY A
# 1052               ASHLEY,  DANIEL J
# 1149                AVILES,  NEREIDA
# 1158                 AYAKHAN,  KEVIN
# 1216            BADILLO,  KRISTIAN E
# 1419                BANNON,  BRIAN A
# 1420               BANNON,  EDWARD L
# 1431                 BAPAT,  RUPAL D
# 1485              BARKER,  WILLIAM L
# 1633            BATEMAN,  KELLY ANNE
# ...
